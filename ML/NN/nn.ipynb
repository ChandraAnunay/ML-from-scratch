# %% [markdown]
# 1 Input Layer -
# 1 Hidden Layer -
# 1 Output Layer

# %%
import numpy as np

# %%
# relu activation function
def relu(x):
    return max(x,0)

# sigmoid activation
def sigmoid(x):
    return 1/(1+np.exp(-x))

# forward feeding
def forward_feed(w,a_0,b,f):
    # activations at hidden layer
    Z1 = np.matmul(w.T,a_0)+b
    a1_new = f(Z1)
    temp = np.exp(a1_new)
    a2_new = temp/np.sum(temp)
    return a2_new

# loss function
def Loss(y_true_vec, y_pred_vec):
    return np.sum((y_true_vec-y_pred_vec)**2)

# back_propagate
def back_propagate():
